# %%
# src/data_prep.py
import pandas as pd
import numpy as np

def load_data(path):
    df = pd.read_csv(path)
    return df

def basic_clean(df):
    # Drop duplicates
    df = df.drop_duplicates(subset='ID', keep='first') if 'ID' in df.columns else df.drop_duplicates()
    # Standardize column names
    df.columns = [c.strip() for c in df.columns]
    # Convert numeric columns
    for col in ['Price_in_Lakhs','Price_per_SqFt','Size_in_SqFt','BHK','Year_Built','Floor_No','Total_Floors']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    return df

def impute_missing(df):
    # numeric impute with medians
    num_cols = df.select_dtypes(include=['float','int']).columns
    for c in num_cols:
        df[c].fillna(df[c].median(), inplace=True)
    # categorical impute with mode or 'Unknown'
    cat_cols = df.select_dtypes(include=['object']).columns
    for c in cat_cols:
        df[c].fillna(df[c].mode().iloc[0] if not df[c].mode().empty else 'Unknown', inplace=True)
    return df

def feature_engineering(df, current_year=2025):
    if 'Price_per_SqFt' not in df.columns and 'Price_in_Lakhs' in df.columns and 'Size_in_SqFt' in df.columns:
        # Price_in_Lakhs to rupees not necessary; keep as lakhs per spec
        df['Price_per_SqFt'] = (df['Price_in_Lakhs'] * 1e5) / df['Size_in_SqFt']
    if 'Age_of_Property' not in df.columns and 'Year_Built' in df.columns:
        df['Age_of_Property'] = current_year - df['Year_Built']
        df.loc[df['Age_of_Property'] < 0, 'Age_of_Property'] = df['Age_of_Property'].median()
    # amenities count
    if 'Amenities' in df.columns:
        df['Amenities_count'] = df['Amenities'].fillna('').apply(lambda x: len(str(x).split(',')) if x!='' else 0)
    # binary flags
    df['has_parking'] = df.get('Parking_Space', 0).apply(lambda x: 1 if (pd.notna(x) and int(x) > 0) else 0) if 'Parking_Space' in df.columns else 0
    df['is_ready_to_move'] = df.get('Availability_Status','').str.lower().apply(lambda x: 1 if 'ready' in str(x) else 0)
    # city median pps for relative feature
    if 'City' in df.columns and 'Price_per_SqFt' in df.columns:
        city_med = df.groupby('City')['Price_per_SqFt'].transform('median')
        df['pps_vs_city_median'] = df['Price_per_SqFt'] / city_med
    return df

def create_labels(df, city_growth_rates=None, global_rate=0.08, threshold_appreciation=0.20):
    # create future price using deterministic formula (fallback)
    if city_growth_rates is None:
        df['growth_rate'] = global_rate
    else:
        df['growth_rate'] = df['City'].map(city_growth_rates).fillna(global_rate)
    df['Future_Price_5yr'] = df['Price_in_Lakhs'] * ((1 + df['growth_rate']) ** 5)
    # Good investment: either >= threshold_appreciation or price below city median
    if 'Price_per_SqFt' in df.columns:
        city_pps_med = df.groupby('City')['Price_per_SqFt'].transform('median')
        df['cheap_vs_city'] = (df['Price_per_SqFt'] <= 0.95 * city_pps_med).astype(int)
    else:
        df['cheap_vs_city'] = 0
    df['expected_appreciation'] = (df['Future_Price_5yr'] - df['Price_in_Lakhs']) / df['Price_in_Lakhs']
    # multi-factor score
    df['mf_score'] = 0
    df['mf_score'] += (df.get('BHK',0) >= 3).astype(int)
    df['mf_score'] += (df.get('is_ready_to_move',0) == 1).astype(int)
    # assume RERA info in Owner_Type or a specific column
    if 'RERA' in df.columns:
        df['mf_score'] += (df['RERA'].astype(str).str.lower().isin(['yes','true','1'])).astype(int)
    df['Good_Investment'] = ((df['expected_appreciation'] >= threshold_appreciation) | (df['cheap_vs_city'] == 1) | (df['mf_score'] >= 2)).astype(int)
    return df

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (2.3.1)Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\ramka\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\docker\\_version.py'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: scikit-learn in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 3)) (1.7.2)
# Requirement already satisfied: xgboost in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: matplotlib in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 5)) (3.10.6)
# Requirement already satisfied: seaborn in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Collecting mlflow (from -r requirements.txt (line 7))
#   Using cached mlflow-3.7.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: streamlit in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 8)) (1.49.1)
# Requirement already satisfied: joblib in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 9)) (1.5.2)
# Requirement already satisfied: plotly in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 10)) (6.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramka\appdata\roaming\python\python312\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramka\appdata\roaming\python\python312\site-packages (from matplotlib->-r requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.4)
# Collecting mlflow-skinny==3.7.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached mlflow_skinny-3.7.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.7.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached mlflow_tracing-3.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow->-r requirements.txt (line 7))
#   Using cached flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (1.17.1)
# Collecting cryptography<47,>=43.0.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow->-r requirements.txt (line 7))
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->-r requirements.txt (line 7))
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: huey<3,>=2.5.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (2.5.5)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (21.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (2.0.36)
# Requirement already satisfied: waitress<4 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (8.1.7)
# Collecting cloudpickle<4 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached databricks_sdk-0.74.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached fastapi-0.124.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (3.1.45)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (6.32.1)
# Collecting pydantic<3,>=2.0.0 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: Mako in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 7)) (1.3.10)
# Requirement already satisfied: colorama in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from cryptography<47,>=43.0.0->mlflow->-r requirements.txt (line 7)) (2.0.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\ramka\appdata\roaming\python\python312\site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 7)) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 7)) (2.5.0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (5.0.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 7))
#   Using cached graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 7))
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (3.23.0)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ramka\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from uvicorn<1->mlflow-skinny==3.7.0->mlflow->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (5.5.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (6.0.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ramka\appdata\roaming\python\python312\site-packages (from streamlit->-r requirements.txt (line 8)) (6.4.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: pycparser in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow->-r requirements.txt (line 7)) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ramka\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.27.1)
# Using cached mlflow-3.7.0-py3-none-any.whl (8.9 MB)
# Using cached mlflow_skinny-3.7.0-py3-none-any.whl (2.4 MB)
# Using cached mlflow_tracing-3.7.0-py3-none-any.whl (1.3 MB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached databricks_sdk-0.74.0-py3-none-any.whl (764 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached fastapi-0.124.2-py3-none-any.whl (112 kB)
# Using cached flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, rsa, pydantic-core, pyasn1-modules, opentelemetry-proto, importlib_metadata, graphql-core, cloudpickle, annotated-types, annotated-doc, uvicorn, starlette, pydantic, opentelemetry-api, graphql-relay, google-auth, docker, cryptography, opentelemetry-semantic-conventions, graphene, Flask-CORS, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    - --------------------------------------  1/27 [rsa]
#    -- -------------------------------------  2/27 [pydantic-core]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ---- -----------------------------------  3/27 [pyasn1-modules]
#    ----- ----------------------------------  4/27 [opentelemetry-proto]
#    ----- ----------------------------------  4/27 [opentelemetry-proto]
#    ----- ----------------------------------  4/27 [opentelemetry-proto]
#    ----- ----------------------------------  4/27 [opentelemetry-proto]
#    ------- --------------------------------  5/27 [importlib_metadata]
#    ------- --------------------------------  5/27 [importlib_metadata]
#    ------- --------------------------------  5/27 [importlib_metadata]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    -------- -------------------------------  6/27 [graphql-core]
#    ---------- -----------------------------  7/27 [cloudpickle]
#    ------------- --------------------------  9/27 [annotated-doc]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    -------------- ------------------------- 10/27 [uvicorn]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ---------------- ----------------------- 11/27 [starlette]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ----------------- ---------------------- 12/27 [pydantic]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    ------------------- -------------------- 13/27 [opentelemetry-api]
#    -------------------- ------------------- 14/27 [graphql-relay]
#    -------------------- ------------------- 14/27 [graphql-relay]
#    -------------------- ------------------- 14/27 [graphql-relay]
#    -------------------- ------------------- 14/27 [graphql-relay]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ---------------------- ----------------- 15/27 [google-auth]
#    ----------------------- ---------------- 16/27 [docker]
